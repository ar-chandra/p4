# %%
import numpy as np
import glob
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
img = mpimg.imread('test_images/sobel_test.jpg')
img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)

# %%
src = np.array([[[675, 480],[1008, 720],[100, 720],[518, 480]]])
dst= np.array([[[960, 0], [960, 720], [200, 720], [200, 0]]])

cv2.fillPoly( img, src, 255 )
#cv2.fillPoly( img, dst, (100,20,100))

                 
plt.imshow(img)
plt.show()
